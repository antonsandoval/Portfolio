# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
input = 'Electric+Disturbance+Events/DOE_Electric_Disturbance_Events.xlsx'

# %%
df_02 = pd.read_excel(input, header=1, sheet_name='2002')

# Overhaul column names for uniformity across different Excel sheets
df_02.rename(columns={'Date':'Date Event Began','Area':'Area Affected',
                      'Number of Customers Affected 1': 'Number of Customers Affected', 
                      'Restoration Time':'Date of Restoration',
                      'Type of Disturbance':'Event Type',
                      'Loss (megawatts)':'Demand Loss (MW)'},
                      inplace=True)
# df_02.drop([0, 2, 5, 7, 9, 12, 16, 21, 23, 28, 36, 37, 38], inplace=True)

df_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              34 non-null     object
#  1   NERC Region                   23 non-null     object
#  2   Time                          23 non-null     object
#  3   Area Affected                 25 non-null     object
#  4   Event Type                    24 non-null     object
#  5   Demand Loss (MW)              19 non-null     object
#  6   Number of Customers Affected  23 non-null     object
#  7   Date of Restoration           22 non-null     object
# dtypes: object(8)
# memory usage: 2.6+ KB

# %%
# df_02 = df_02.drop([11, 26, 31])
df_02.drop(columns='Time', inplace=True)
df_02['Date Event Began'] = pd.to_datetime(df_02['Date Event Began'], errors='coerce')
df_02 = df_02.dropna(subset=['Date Event Began'])
df_02.reset_index(drop=True, inplace=True)

df_02.head()
# Out:
#   Date Event Began NERC Region                  Area Affected  \
# 0       2002-01-30         SPP                       Oklahoma
# 1       2002-01-29         SPP  Metropolitan Kansas City Area
# 2       2002-01-30         SPP                       Missouri
# 3       2002-02-27        WSCC                     California
# 4       2002-03-09        ECAR    Lower Peninsula of Michigan
#
#                   Event Type Demand Loss (MW) Number of Customers Affected  \
# 0                  Ice Storm              500                      1881134
# 1                  Ice Storm          500-600                       270000
# 2                  Ice Storm              210                        95000
# 3  Interruption of Firm Load              300                       255000
# 4             Severe Weather              190                       190000
#
#    Date of Restoration
# 0  2002-02-07 12:00:00
# 1                  NaN
# 2  2002-02-10 21:00:00
# 3  2002-02-27 11:35:00
# 4  2002-03-11 12:00:00

# %%
df_03 = pd.read_excel(input, header=1, sheet_name='2003')
df_03.rename(columns={'Date':'Date Event Began',
                      'Number of Customers Affected 1': 'Number of Customers Affected',
                      'Restoration':'Date of Restoration',
                      'Type of Disturbance':'Event Type',
                      'Loss (megawatts)':'Demand Loss (MW)'},
                      inplace=True)

df_03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              87 non-null     object
#  1   NERC Region                   65 non-null     object
#  2   Time                          63 non-null     object
#  3   Area Affected                 73 non-null     object
#  4   Event Type                    64 non-null     object
#  5   Demand Loss (MW)              60 non-null     object
#  6   Number of Customers Affected  60 non-null     object
#  7   Date of Restoration           69 non-null     object
# dtypes: object(8)
# memory usage: 7.4+ KB

# %%
df_03['Date Event Began'] = pd.to_datetime(df_03['Date Event Began'], errors='coerce')
df_03 = df_03.dropna(subset=['Date Event Began'])
df_03.reset_index(drop=True, inplace=True)
df_03.drop(columns='Time', inplace=True)

df_03.head()
# Out:
#   Date Event Began NERC Region              Area Affected  \
# 0       2003-01-25        ECAR           Cincinnati, Ohio
# 1       2003-02-27        SERC   Piedmont, North Carolina
# 2       2003-04-03        ECAR  Lower Michigan Peninsula
# 3       2003-04-04        NPCC                 New York,
# 4       2003-04-15       ERCOT           Cities of Bryan,
#
#                     Event Type Demand Loss (MW) Number of Customers Affected  \
# 0  Cyber Threat From Internet               NaN                          NaN
# 1             Winter Ice Storm             1000                 over 340,000
# 2                    Ice Storm              300                       425000
# 3                Severe Storm           200-250                       160000
# 4         Relaying Malfunction              212                        68530
#
#    Date of Restoration
# 0   1/26/03, 2:00 a.m.
# 1   3/01/03, 8:00 a.m.
# 2  4/06/03, 5:00 p.m.
# 3  4/05/03, 2:00 p.m.
# 4  4/15/03, 2:06 p.m.

# %%
df_04 = pd.read_excel(input, header=1, sheet_name='2004')
df_04.rename(columns={'Date':'Date Event Began', 'Number of Customers Affected 1': 'Number of Customers Affected',
                      'Restoration':'Date of Restoration', 'Type of Disturbance':'Event Type', 'Loss (megawatts)':'Demand Loss (MW)'}, inplace=True)

df_04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              120 non-null    object
#  1   NERC Region                   101 non-null    object
#  2   Time                          97 non-null     object
#  3   Area Affected                 97 non-null     object
#  4   Event Type                    97 non-null     object
#  5   Demand Loss (MW)              98 non-null     object
#  6   Number of Customers Affected  98 non-null     object
#  7   Date of Restoration           102 non-null    object
# dtypes: object(8)
# memory usage: 8.5+ KB

# %%
df_04['Date Event Began'] = pd.to_datetime(df_04['Date Event Began'], errors='coerce')
df_04 = df_04.dropna(subset=['Date Event Began'])
df_04.reset_index(drop=True, inplace=True)
df_04.drop(columns='Time', inplace=True)

df_04.head()
# Out:
#   Date Event Began NERC Region                  Area Affected  \
# 0       2004-01-01        WECC            Northern California
# 1       2004-01-07        WECC                    King County
# 2       2004-01-08        NPCC  Lake Placid/Saranac, New York
# 3       2004-01-14        NPCC  Lake Placid/Saranac, New York
# 4       2004-01-26       SERC          Central South Carolina
#
#                      Event Type Demand Loss (MW) Number of Customers Affected  \
# 0                  Winter Storm              170                       263000
# 1                    Snow Storm              150                       145000
# 2  Public Appeal to Reduce Load              100                        18600
# 3  Public Appeal to Reduce Load              100                        18600
# 4                     Ice Storm          500-700                       150000
#
#    Date of Restoration
# 0   1/02/04, 4:00 p.m.
# 1   1/10/04, 5:00 p.m.
# 2   1/10/04, 7:00 p.m.
# 3  1/17/04, 12:00 noon
# 4   1/28/04, 8:00 a.m.

# %%
df_05 = pd.read_excel(input, header=1, sheet_name='2005')
df_05.rename(columns={'Date':'Date Event Began', 'Number of Customers Affected 1': 'Number of Customers Affected',
                      'Restoration':'Date of Restoration', 'Type of Disturbance':'Event Type', 'Loss (megawatts)':'Demand Loss (MW)'}, inplace=True)

df_05.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              112 non-null    object
#  1   NERC Region                   93 non-null     object
#  2   Time                          88 non-null     object
#  3   Area Affected                 89 non-null     object
#  4   Event Type                    89 non-null     object
#  5   Demand Loss (MW)              79 non-null     object
#  6   Number of Customers Affected  82 non-null     object
#  7   Date of Restoration           94 non-null     object
# dtypes: object(8)
# memory usage: 8.1+ KB

# %%
df_05['Date Event Began'] = pd.to_datetime(df_05['Date Event Began'], errors='coerce')
df_05 = df_05.dropna(subset=['Date Event Began'])
df_05.reset_index(drop=True, inplace=True)
df_05.drop(columns='Time', inplace=True)

df_05.head(10)
# Out:
#   Date Event Began NERC Region                              Area Affected  \
# 0       2005-01-04         SPP   Eastern one third of the state of Kansas
# 1       2005-01-05        ECAR                  Akron and Mansfield areas
# 2       2005-01-05        ECAR  Indiana Michigan Region - Muncie District
# 3       2005-01-07        WECC                        Northern California
# 4       2005-01-19          PR                      Island of Puerto Rico
# 5       2005-01-23          PR                      Island of Puerto Rico
# 6       2005-01-24          PR                      Island of Puerto Rico
# 7       2005-01-24          PR                      Island of Puerto Rico
# 8       2005-01-29        SERC               Parts of Alabama and Georgia
# 9       2005-01-29        SERC                                    Georgia
#
#                     Event Type Demand Loss (MW) Number of Customers Affected  \
# 0                 Winter Storm              200                       211000
# 1                    Ice Storm              250                       246990
# 2             Winter Ice Storm              545                       114791
# 3                 Winter Storm              120                       442000
# 4            Voltage Reduction              209                          NaN
# 5            Voltage Reduction              140                          NaN
# 6  Voltage Reduction/Shed Load              225                        70717
# 7  Voltage Reduction/Shed Load              385                          NaN
# 8                    Ice Storm              100                       150000
# 9                    Ice Storm        65 to 100                        82000
#
#      Date of Restoration
# 0    1/14/05, 12:00 p.m.
# 1     1/13/05, 6:00 p.m.
# 2    1/16/05, 11:00 a.m.
# 3     1/10/05, 8:00 a.m.
# 4     1/19/05, 9:27 a.m.
# 5  1/23/05, 11:24 a.m.
# 6     1/24/05, 6:50 a.m.
# 7    1/24/05, 12:34 p.m.
# 8     1/31/05, 10:00 a.m
# 9     1/30/05, 3:00 p.m.

# %%
df_06 = pd.read_excel(input, header=1, sheet_name='2006')
df_06.rename(columns={'Date':'Date Event Began', 'Number of Customers Affected 1': 'Number of Customers Affected',
                      'Restoration':'Date of Restoration', 'Type of Disturbance':'Event Type', 'Loss (megawatts)':'Demand Loss (MW)'}, inplace=True)

df_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              112 non-null    object
#  1   NERC Region                   94 non-null     object
#  2   Time                          94 non-null     object
#  3   Area Affected                 94 non-null     object
#  4   Event Type                    94 non-null     object
#  5   Demand Loss (MW)              75 non-null     object
#  6   Number of Customers Affected  87 non-null     object
#  7   Date of Restoration           94 non-null     object
# dtypes: object(8)
# memory usage: 7.1+ KB

# %%
df_06['Date Event Began'] = pd.to_datetime(df_06['Date Event Began'], errors='coerce')
df_06 = df_06.dropna(subset=['Date Event Began'])
df_06.reset_index(drop=True, inplace=True)
df_06.drop(columns='Time', inplace=True)

df_06.head(10)
# Out:
#   Date Event Began NERC Region  \
# 0       2006-01-14         RFC
# 1       2006-01-18        NPCC
# 2       2006-02-04        WECC
# 3       2006-02-04        WECC
# 4       2006-02-11         RFC
# 5       2006-02-12         RFC
# 6       2006-02-12         RFC
# 7       2006-02-12         RFC
# 8       2006-02-12         RFC
# 9       2006-02-16         RFC
#
#                                        Area Affected  \
# 0  Chester, Montgomery, Delaware, Philadelphia an...
# 1                         Southern and Central Maine
# 2                       Snohomish County, Washington
# 3                                 Western Washington
# 4        Baltimore Metropolitan and Central Maryland
# 5  Washington DC, Montgomery and Prince Georges C...
# 6  Entire Atlantic City Electric territory Southe...
# 7            Entire Delmarva Power service territory
# 8                 Northern and Northwestern Virginia
# 9  Muskegon, Michigan easterly to Bay City, Michigan
#
#                             Event Type Demand Loss (MW)  \
# 0                           High Winds               --
# 1                         Severe Storm               75
# 2                         Strong Winds              150
# 3                     Severe Windstorm               --
# 4                     Major Snow Storm              500
# 5                     Major Snow Storm              300
# 6                Winter Snow/Ice Storm               80
# 7                Winter Snow/Ice Storm               50
# 8                    Severe Snow Storm              250
# 9  Severe Thunderstorm/ Snow/Ice Storm              100
#
#   Number of Customers Affected      Date of Restoration
# 0                       142315     5:30 p.m. January 16
# 1                        63000     6:34 p.m. January 18
# 2                       123827   12:01 a.m. February 06
# 3                       140000   8:00  a.m. February 08
# 4                       180000   11:00 p.m. February 14
# 5                        60000  5:44 p.m.   February 14
# 6                       130000    4:00 p.m. February 14
# 7                        58000    7:00 a.m. February 13
# 8                       126000    2:00 p.m. February 12
# 9                       252089   11:00 p.m. February 20

# %%
df_07 = pd.read_excel(input, header=1, sheet_name='2007')
df_07.rename(columns={'Date':'Date Event Began', ' NERC Region': 'NERC Region', 'Number of Customers Affected 1[1]': 'Number of Customers Affected', 
                      'Restoration':'Date of Restoration', 'Type of Disturbance':'Event Type', 'Loss (megawatts)':'Demand Loss (MW)'}, inplace=True)
df_07.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              97 non-null     object
#  1   NERC Region                   80 non-null     object
#  2   Time                          80 non-null     object
#  3   Area Affected                 80 non-null     object
#  4   Event Type                    80 non-null     object
#  5   Demand Loss (MW)              62 non-null     object
#  6   Number of Customers Affected  68 non-null     object
#  7   Date of Restoration           80 non-null     object
# dtypes: object(8)
# memory usage: 6.2+ KB

# %%
df_07['Date Event Began'] = pd.to_datetime(df_07['Date Event Began'], errors='coerce')
df_07 = df_07.dropna(subset=['Date Event Began'])
df_07.reset_index(drop=True, inplace=True)
df_07.drop(columns='Time', inplace=True)

df_07.head(10)
# Out:
#   Date Event Began NERC Region  \
# 0       2007-01-05          PR
# 1       2007-01-13         MRO
# 2       2007-01-13         RFC
# 3       2007-01-16        WECC
# 4       2007-02-13         RFC
# 5       2007-02-13         RFC
# 6       2007-02-24         MRO
# 7       2007-02-24         MRO
# 8       2007-02-24         RFC
# 9       2007-02-28        WECC
#
#                                        Area Affected         Event Type  \
# 0                              Island of Puerto Rico  Voltage Reduction
# 1                              Missouri and Illinois          Ice Storm
# 2                         Eastern and Lower Michigan          Ice Storm
# 3                       Snohomish County, Washington    Major Windstorm
# 4                         Indiana and Southwest Ohio     Ice/Wind Storm
# 5                                   Central Maryland       Winter Storm
# 6  NE quarter of State of Iowa and Rock Island, I...          Ice Storm
# 7                Central Iowa and Cedar Rapids areas          Ice Storm
# 8                                 Cedar Rapids, Iowa          Ice Storm
# 9                                Northern California       Winter Storm
#
#   Demand Loss (MW) Number of Customers Affected     Date of Restoration
# 0                0                            0   11:13 a.m. January 05
# 1              NaN                       225000   12:00 p.m. January 19
# 2              500                       129607    4:00 p.m. January 19
# 3              260                       110433   12:00 a.m. January 17
# 4              250                       367500  12:00 a.m. February 16
# 5              400                       155183   5:30 a.m. February 17
# 6              210                        75000     12:57 a.m. March 04
# 7              400                       140000  11:47 p.m. February 24
# 8              750                       215000  12:47 a.m. February 25
# 9              110                       671189      8:45 p.m. March 02

# %%
df_08 = pd.read_excel(input, header=1, sheet_name='2008')
df_08.rename(columns={'Date':'Date Event Began', 'Number of Customers Affected 1': 'Number of Customers Affected', 
                      'Restoration':'Date of Restoration', 'Type of Disturbance':'Event Type', 'Loss (megawatts)':'Demand Loss (MW)'}, inplace=True)
df_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              174 non-null    object
#  1   NERC Region                   154 non-null    object
#  2   Time                          154 non-null    object
#  3   Area Affected                 154 non-null    object
#  4   Event Type                    154 non-null    object
#  5   Demand Loss (MW)              101 non-null    object
#  6   Number of Customers Affected  151 non-null    object
#  7   Date of Restoration           161 non-null    object
# dtypes: object(8)
# memory usage: 12.0+ KB

# %%
df_08['Date Event Began'] = pd.to_datetime(df_08['Date Event Began'], errors='coerce')
df_08 = df_08.dropna(subset=['Date Event Began'])
df_08.reset_index(drop=True, inplace=True)
df_08.drop(columns='Time', inplace=True)

df_08.head(10)
# Out:
#   Date Event Began NERC Region                             Area Affected  \
# 0       2008-01-04        WECC                       Northern California
# 1       2008-01-04        WECC                         Sacramento County
# 2       2008-01-29        WECC        San Francisco Bay Area, California
# 3       2008-01-29        SERC    Arkansas, Mississippi, North Louisiana
# 4       2008-01-29         RFC                     Southeastern Michigan
# 5       2008-01-29         RFC  South Metropolitan Areas of Dayton, OHio
# 6       2008-01-30        NPCC                         Western, New York
# 7       2008-02-01        WECC        San Francisco Bay Area, California
# 8       2008-02-02        WECC        San Francisco Bay Area, California
# 9       2008-02-05        SERC                         State of Kentucky
#
#              Event Type Demand Loss (MW) Number of Customers Affected  \
# 0          Winter Storm              500                      2606931
# 1          Severe Storm              300                       150000
# 2       Exciter Faulted              NaN                            -
# 3  Severe Thunderstorms              NaN                       110000
# 4        Wind/Ice Storm              NaN                        86915
# 5            High Winds              380                        45000
# 6            High Winds               50                        54316
# 7     Equipment Faulted              NaN                            -
# 8     Equipment Faulted              NaN                            -
# 9        Severe Weather              NaN                        76000
#
#      Date of Restoration
# 0   5:00 p.m. January 14
# 1   4:30 p.m. January 04
# 2  12:17 p.m. January 29
# 3   8:00 a.m February 03
# 4  6:30 p.m. February 01
# 5  12:48 a.m. January 30
# 6  2:50 p.m. February 01
# 7  7:49 a.m. February 01
# 8  4:27 p.m. February 02
# 9  3:00 a.m. February 06

# %%
df_09 = pd.read_excel(input, header=1, sheet_name='2009')
df_09.rename(columns={'Date':'Date Event Began', 'Number of Customers Affected 1': 'Number of Customers Affected', 
                      'Restoration':'Date of Restoration', 'Type of Disturbance':'Event Type', 'Loss (megawatts)':'Demand Loss (MW)'}, inplace=True)
df_09.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              115 non-null    object
#  1   NERC Region                   99 non-null     object
#  2   Time                          99 non-null     object
#  3   Area Affected                 99 non-null     object
#  4   Event Type                    99 non-null     object
#  5   Demand Loss (MW)              59 non-null     object
#  6   Number of Customers Affected  82 non-null     object
#  7   Date of Restoration           103 non-null    object
# dtypes: object(8)
# memory usage: 7.9+ KB

# %%
df_09['Date Event Began'] = pd.to_datetime(df_09['Date Event Began'], errors='coerce')
df_09 = df_09.dropna(subset=['Date Event Began'])
df_09.reset_index(drop=True, inplace=True)
df_09.drop(columns='Time', inplace=True)

df_08.head(10)
# Out:
#   Date Event Began NERC Region                             Area Affected  \
# 0       2008-01-04        WECC                       Northern California
# 1       2008-01-04        WECC                         Sacramento County
# 2       2008-01-29        WECC        San Francisco Bay Area, California
# 3       2008-01-29        SERC    Arkansas, Mississippi, North Louisiana
# 4       2008-01-29         RFC                     Southeastern Michigan
# 5       2008-01-29         RFC  South Metropolitan Areas of Dayton, OHio
# 6       2008-01-30        NPCC                         Western, New York
# 7       2008-02-01        WECC        San Francisco Bay Area, California
# 8       2008-02-02        WECC        San Francisco Bay Area, California
# 9       2008-02-05        SERC                         State of Kentucky
#
#              Event Type Demand Loss (MW) Number of Customers Affected  \
# 0          Winter Storm              500                      2606931
# 1          Severe Storm              300                       150000
# 2       Exciter Faulted              NaN                            -
# 3  Severe Thunderstorms              NaN                       110000
# 4        Wind/Ice Storm              NaN                        86915
# 5            High Winds              380                        45000
# 6            High Winds               50                        54316
# 7     Equipment Faulted              NaN                            -
# 8     Equipment Faulted              NaN                            -
# 9        Severe Weather              NaN                        76000
#
#      Date of Restoration
# 0   5:00 p.m. January 14
# 1   4:30 p.m. January 04
# 2  12:17 p.m. January 29
# 3   8:00 a.m February 03
# 4  6:30 p.m. February 01
# 5  12:48 a.m. January 30
# 6  2:50 p.m. February 01
# 7  7:49 a.m. February 01
# 8  4:27 p.m. February 02
# 9  3:00 a.m. February 06

# %%
df_10 = pd.read_excel(input, header=1, sheet_name='2010')
df_10.rename(columns={'Date':'Date Event Began', 'Number of Customers Affected 1': 'Number of Customers Affected', 
                      'Restoration':'Date of Restoration', 'Type of Disturbance':'Event Type', 'Loss (megawatts)':'Demand Loss (MW)'}, inplace=True)
df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              144 non-null    object
#  1   NERC Region                   126 non-null    object
#  2   Time                          126 non-null    object
#  3   Area Affected                 126 non-null    object
#  4   Event Type                    126 non-null    object
#  5   Demand Loss (MW)              55 non-null     object
#  6   Number of Customers Affected  94 non-null     object
#  7   Date of Restoration           126 non-null    object
# dtypes: object(8)
# memory usage: 9.1+ KB

# %%
df_10['Date Event Began'] = pd.to_datetime(df_10['Date Event Began'], errors='coerce')
df_10 = df_10.dropna(subset=['Date Event Began'])
df_10.reset_index(drop=True, inplace=True)
df_10.drop(columns='Time', inplace=True)
df_10.head(10)
# Out:
#   Date Event Began NERC Region                    Area Affected  \
# 0       2010-01-06       SERC               Southwest Louisiana
# 1       2010-01-11  FRCC/SERC      Northern and Central Florida
# 2       2010-01-18       WECC   Northern and Central California
# 3       2010-01-19       WECC                     San Francisco
# 4       2010-01-19       WECC     San Diego and Orange Counties
# 5       2010-01-20       WECC   City of Los Angeles, California
# 6       2010-01-28        SPP                          Oklahoma
# 7       2010-02-01        SPP                          Oklahoma
# 8       2010-02-05        RFC                       Southern NJ
# 9       2010-02-05       SERC          North and South Carolina
#
#                                     Event Type Demand Loss (MW)  \
# 0                          Made Public Appeals              NaN
# 1  Interruptible Load Shed/Made Public Appeals              NaN
# 2                                 Severe Storm              290
# 3                                 Severe Storm              300
# 4                                 Severe Storm             2650
# 5                                 Severe Storm              NaN
# 6                                    Ice Storm              NaN
# 7       Ice Storm/Electrical System Separation               30
# 8                                 Winter Storm              NaN
# 9                                 Winter Storm              500
#
#   Number of Customers Affected     Date of Restoration
# 0                          NaN    6:00 p.m. January 08
# 1                          NaN    9:57 a.m. January 11
# 2                      1700000    8:00 a.m. January 28
# 3                        30000   12:24 p.m. January 19
# 4                        50000    3:00 p.m. January 20
# 5                       147223    6:10 p.m. January 24
# 6                        68705  12:00 p.m. February 02
# 7                            0   5:00 p.m. February 01
# 8                       221000   4:00 p.m. February 13
# 9                        74000   5:00 p.m. February 07

# %%
df_11 = pd.read_excel(input, header=1, sheet_name='2011')
df_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date Event Began              320 non-null    object
#  1   Time Event Began              307 non-null    object
#  2   Date of Restoration           307 non-null    datetime64[ns]
#  3   Time of Restoration           307 non-null    object
#  4   Area Affected                 307 non-null    object
#  5   NERC Region                   304 non-null    object
#  6   Event Type                    307 non-null    object
#  7   Demand Loss (MW)              236 non-null    object
#  8   Number of Customers Affected  262 non-null    object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 22.7+ KB

# %%
df_11['Date Event Began'] = pd.to_datetime(df_11['Date Event Began'], errors='coerce')
df_11 = df_11.dropna(subset=['Date Event Began'])
df_11.reset_index(drop=True, inplace=True)
df_11.drop(columns=['Time Event Began', 'Time of Restoration'], inplace=True)

df_11.head(10)
# Out:
#   Date Event Began Date of Restoration  \
# 0       2011-01-11          2011-01-11
# 1       2011-01-12          2011-01-12
# 2       2011-01-13          2011-01-13
# 3       2011-01-18          2011-01-18
# 4       2011-01-23          2011-01-23
# 5       2011-01-24          2011-01-24
# 6       2011-01-25          2011-01-25
# 7       2011-01-26          2011-01-27
# 8       2011-01-26          2011-01-27
# 9       2011-01-26          2011-01-31
#
#                                        Area Affected NERC Region  \
# 0                                   Athens, New York        NPCC
# 1                                      Massachusetts        NPCC
# 2                                      North Florida        FRCC
# 3       Whitman, Auburn St Substation, Massachusetts        NPCC
# 4                             Franklin County, Idaho        WECC
# 5                          Newman Power Plant, Texas        WECC
# 6                                   Newark, Delaware         RFC
# 7                                Carson City, Nevada        WECC
# 8                                           Michigan         RFC
# 9  Montgomery and Prince George's County, Marylan...         RFC
#
#                             Event Type Demand Loss (MW)  \
# 0        Electrical Fault at Generator                0
# 1                         Winter Storm              NaN
# 2                Firm System Load Shed              150
# 3                            Vandalism                0
# 4                            Vandalism                0
# 5                  Suspicious Activity                0
# 6                            Vandalism                0
# 7  Suspected Telecommunications Attack                0
# 8                            Vandalism                0
# 9                         Winter Storm              NaN
#
#   Number of Customers Affected
# 0                            0
# 1                        80000
# 2                        20900
# 3                            0
# 4                            0
# 5                            0
# 6                            0
# 7                            0
# 8                            0
# 9                       210000

# %%
df_02 = df_02[['Date Event Began', 'Date of Restoration', 'Area Affected', 'NERC Region', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected']]
df_03 = df_03[['Date Event Began', 'Date of Restoration', 'Area Affected', 'NERC Region', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected']]
df_04 = df_04[['Date Event Began', 'Date of Restoration', 'Area Affected', 'NERC Region', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected']]
df_05 = df_05[['Date Event Began', 'Date of Restoration', 'Area Affected', 'NERC Region', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected']]
df_06 = df_06[['Date Event Began', 'Date of Restoration', 'Area Affected', 'NERC Region', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected']]
df_07 = df_07[['Date Event Began', 'Date of Restoration', 'Area Affected', 'NERC Region', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected']]
df_08 = df_08[['Date Event Began', 'Date of Restoration', 'Area Affected', 'NERC Region', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected']]
df_09 = df_09[['Date Event Began', 'Date of Restoration', 'Area Affected', 'NERC Region', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected']]
df_10 = df_10[['Date Event Began', 'Date of Restoration', 'Area Affected', 'NERC Region', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected']]

# %%
df_12 = pd.read_excel(input, header=1, sheet_name='2012')
df_12['Date Event Began'] = pd.to_datetime(df_12['Date Event Began'], errors='coerce')
df_12 = df_12.dropna(subset=['Date Event Began'])
df_12.reset_index(drop=True, inplace=True)
df_12.drop(columns=['Time Event Began', 'Time of Restoration'], inplace=True)

df_12
# Out:
#     Date Event Began  Date of Restoration  \
# 0         2012-01-04  2012-01-04 00:00:00
# 1         2012-01-05  2012-01-05 00:00:00
# 2         2012-01-05  2012-01-05 00:00:00
# 3         2012-01-09  2012-01-09 00:00:00
# 4         2012-01-09  2012-01-11 00:00:00
# ..               ...                  ...
# 191       2012-12-17  2012-12-17 00:00:00
# 192       2012-12-25  2012-12-28 00:00:00
# 193       2012-12-25  2012-12-26 00:00:00
# 194       2012-12-26  2012-12-26 00:00:00
# 195       2012-12-31  2012-12-31 00:00:00
#
#                                 Area Affected NERC Region  \
# 0                          Tacoma, Washington        WECC
# 1           CSWS/AEP West territory, Oklahoma         SPP
# 2                      Creek County, Oklahoma         SPP
# 3                      Watertown, Connecticut        NPCC
# 4                                   Louisiana        SERC
# ..                                        ...         ...
# 191                        Tacoma, Washington        WECC
# 192  Arkansas; Louisiana; Mississippi; Texas          SPP
# 193                            Houston, Texas         TRE
# 194              Stantonsburg, North Carolina        SERC
# 195                            North Carolina        SERC
#
#                                   Event Type Demand Loss (MW)  \
# 0                  Suspected physical attack              NaN
# 1                                   Sabotage                0
# 2                  Suspected physical attack              NaN
# 3                                  Vandalism              NaN
# 4                                  Load Shed              150
# ..                                       ...              ...
# 191                Suspected Physical Attack                0
# 192            Severe Weather - Winter Storm          Unknown
# 193  Severe Weather - Cold Front, High Winds              294
# 194            Severe Weather - Thunderstorm                3
# 195                Transmission Interruption               40
#
#     Number of Customers Affected
# 0                            NaN
# 1                              0
# 2                            NaN
# 3                            NaN
# 4                              1
# ..                           ...
# 191                            0
# 192                       242509
# 193                       262000
# 194                         1200
# 195                        12000
#
# [196 rows x 7 columns]

# %%
df_13 = pd.read_excel(input, header=1, sheet_name='2013')
df_13['Date Event Began'] = pd.to_datetime(df_13['Date Event Began'], errors='coerce')
df_13 = df_13.dropna(subset=['Date Event Began'])
df_13.reset_index(drop=True, inplace=True)
df_13.drop(columns=['Time Event Began', 'Time of Restoration'], inplace=True)

df_13
# Out:
#     Date Event Began  Date of Restoration  \
# 0         2013-01-07  2013-01-07 00:00:00
# 1         2013-01-16  2013-01-16 00:00:00
# 2         2013-01-16  2013-01-16 00:00:00
# 3         2013-01-16  2013-01-17 00:00:00
# 4         2013-01-17  2013-01-20 00:00:00
# ..               ...                  ...
# 169       2013-12-22  2013-12-28 00:00:00
# 170       2013-12-23  2013-12-25 00:00:00
# 171       2013-12-27  2013-12-27 00:00:00
# 172       2013-12-30  2013-12-30 00:00:00
# 173       2013-12-30  2014-01-01 00:00:00
#
#                                   Area Affected NERC Region  \
# 0                              Denton, Maryland         RFC
# 1                              Denton, Maryland         RFC
# 2                   San Juan County, New Mexico        WECC
# 3                          Webster County, Iowa         MRO
# 4    Southwest Virginia, Southern West Virginia         RFC
# ..                                          ...         ...
# 169         Southern Lower Penninsula, Michigan         RFC
# 170                         Central Maine Maine        NPCC
# 171                            Gilabend Arizona        WECC
# 172                       Salt Lake County Utah        WECC
# 173             North of Roosevelt lake Arizona        WECC
#
#                         Event Type Demand Loss (MW)  \
# 0       Physcial Attack; Vandalism          Unknown
# 1       Physcial Attack; Vandalism          Unknown
# 2        Suspected Physical Attack                0
# 3                  Physical Attack              NaN
# 4    Severe Weather - Winter Storm          Unknown
# ..                             ...              ...
# 169      Severe Weather - Ice/Snow          Unknown
# 170      Severe Weather - Ice/Snow          Unknown
# 171                Physical Attack              NaN
# 172                Physical Attack              NaN
# 173                Physical Attack              NaN
#
#     Number of Customers Affected
# 0                        Unknown
# 1                        Unknown
# 2                              0
# 3                            NaN
# 4                         127000
# ..                           ...
# 169                        50000
# 170                        52500
# 171                          NaN
# 172                          NaN
# 173                          NaN
#
# [174 rows x 7 columns]

# %%
df_14 = pd.read_excel(input, header=1, sheet_name='2014')
df_14['Date Event Began'] = pd.to_datetime(df_14['Date Event Began'], errors='coerce')
df_14 = df_14.dropna(subset=['Date Event Began'])
df_14.reset_index(drop=True, inplace=True)
df_14.drop(columns=['Time Event Began', 'Time of Restoration'], inplace=True)

df_14
# Out:
#     Date Event Began  Date of Restoration  \
# 0         2014-01-06  2014-01-06 00:00:00
# 1         2014-01-06  2014-01-06 00:00:00
# 2         2014-01-06  2014-01-06 00:00:00
# 3         2014-01-06  2014-01-07 00:00:00
# 4         2014-01-06  2014-01-06 00:00:00
# ..               ...                  ...
# 209       2014-12-11  2014-12-11 00:00:00
# 210       2014-12-11  2014-12-12 00:00:00
# 211       2014-12-17  2014-12-17 00:00:00
# 212       2014-12-30  2014-12-31 00:00:00
# 213       2014-12-30  2015-01-01 00:00:00
#
#                                          Area Affected NERC Region  \
# 0                                 District of Columbia         RFC
# 1                                              Unknown         RFC
# 2                                             Delaware         RFC
# 3                                              Unknown         RFC
# 4                                         Pennsylvania         RFC
# ..                                                 ...         ...
# 209                                   Portland, Oregon        WECC
# 210      Kitsap, Thurston, Whatcom counties Washington        WECC
# 211                                         Washington        WECC
# 212  New Hampshire, Massachusetts, Maine, Rhode Isl...        NPCC
# 213                                Northern California        WECC
#
#                                          Event Type Demand Loss (MW)  \
# 0    Voltage Reduction due to Severe Weather - Cold          Unknown
# 1    Voltage Reduction due to Severe Weather - Cold          Unknown
# 2    Voltage Reduction due to Severe Weather - Cold          Unknown
# 3        Public Appeal due to Severe Weather - Cold          Unknown
# 4    Voltage Reduction due to Severe Weather - Cold              200
# ..                                              ...              ...
# 209                      Severe Weather- High Winds              250
# 210                      Severe Weather- High Winds              116
# 211                       Suspected Physical Attack          Unknown
# 212                          Suspected Cyber Attack          Unknown
# 213                      Severe Weather- High Winds              127
#
#     Number of Customers Affected
# 0                        Unknown
# 1                        Unknown
# 2                        Unknown
# 3                        Unknown
# 4                          62000
# ..                           ...
# 209                        85470
# 210                       264000
# 211                      Unknown
# 212                      Unknown
# 213                        84500
#
# [214 rows x 7 columns]

# %%
df_15 = pd.read_excel(input, header=1, sheet_name='2015')
df_15['Date Event Began'] = pd.to_datetime(df_15['Date Event Began'], errors='coerce')
df_15 = df_15.dropna(subset=['Date Event Began'])
df_15.reset_index(drop=True, inplace=True)
df_15.drop(columns=['Month', 'Time Event Began', 'Time of Restoration', 'Alert Criteria'], inplace=True)

df_15
# Out:
#     Date Event Began  Date of Restoration  \
# 0         2015-01-07  2015-01-08 00:00:00
# 1         2015-01-07  2015-01-08 00:00:00
# 2         2015-01-22  2015-01-22 00:00:00
# 3         2015-01-26  2015-01-26 00:00:00
# 4         2015-01-27  2015-01-27 00:00:00
# ..               ...                  ...
# 138       2015-12-27  2015-12-28 00:00:00
# 139       2015-12-27              Unknown
# 140       2015-12-29  2015-12-29 00:00:00
# 141       2015-12-31  2015-12-31 00:00:00
# 142       2015-12-31              Unknown
#
#                                          Area Affected NERC Region  \
# 0                                            Tennessee        SERC
# 1    Tennessee, Kentucky, Virginia, North Carolina,...        SERC
# 2                                     Portland, Oregon        WECC
# 3                                Cave Junction, Oregon        WECC
# 4                                       Kountze, Texas        SERC
# ..                                                 ...         ...
# 138                                           Oklahoma         SPP
# 139                                           Oklahoma         SPP
# 140                                              Maine        NPCC
# 141                           Oklahoma: Blaine County;         SPP
# 142                                           Missouri        SERC
#
#                   Event Type Demand Loss (MW) Number of Customers Affected
# 0    Severe Weather - Winter          Unknown                      Unknown
# 1    Severe Weather - Winter          Unknown                      Unknown
# 2                  Vandalism          Unknown                      Unknown
# 3                  Vandalism          Unknown                      Unknown
# 4                   Sabotage                0                            0
# ..                       ...              ...                          ...
# 138           Severe Weather          Unknown                        54476
# 139           Severe Weather          Unknown                        50500
# 140                 Sabotage                0                            0
# 141           Severe Weather                8                         1500
# 142                 Sabotage                0                            0
#
# [143 rows x 7 columns]

# %%
df_16 = pd.read_excel(input, header=1, sheet_name='2016')
df_16['Date Event Began'] = pd.to_datetime(df_16['Date Event Began'], errors='coerce')
df_16 = df_16.dropna(subset=['Date Event Began'])
df_16.reset_index(drop=True, inplace=True)
df_16.drop(columns=['Month', 'Time Event Began', 'Time of Restoration', 'Alert Criteria'], inplace=True)

df_16
# Out:
#     Date Event Began  Date of Restoration  \
# 0         2016-01-04  2016-01-05 00:00:00
# 1         2016-01-10  2016-01-11 00:00:00
# 2         2016-01-11  2016-01-11 00:00:00
# 3         2016-01-14  2016-01-14 00:00:00
# 4         2016-01-17  2016-01-17 00:00:00
# ..               ...                  ...
# 136       2016-12-16           12/16/2016
# 137       2016-12-26           12/26/2016
# 138       2016-12-28           12/31/2016
# 139       2016-12-30           12/30/2016
# 140       2016-12-30           12/30/2016
#
#                                          Area Affected NERC Region  \
# 0                         Wisconsin: Milwaukee County;         MRO
# 1    Maine: Connecticut: Massachusetts: Vermont: Ne...        NPCC
# 2                        Pennsylvania: Chester County;         RFC
# 3                                            Delaware:         RFC
# 4                              Utah: Salt Lake County;        WECC
# ..                                                 ...         ...
# 136                          Oregon: Multnomah County;        WECC
# 137                                        Washington:        WECC
# 138                                        California:        WECC
# 139                        Vermont: Chittenden County;        NPCC
# 140                                             Maine:        NPCC
#
#                       Event Type Demand Loss (MW) Number of Customers Affected
# 0                       Sabotage                0                            0
# 1                        Weather          Unknown                        59859
# 2                      Vandalism                0                            0
# 3                      Vandalism                0                            0
# 4                       Sabotage                0                            0
# ..                           ...              ...                          ...
# 136                    Vandalism                0                            0
# 137                    Vandalism                0                            0
# 138       Fuel Supply Deficiency                0                            0
# 139                        Other                0                            0
# 140  Weather or Natural Disaster          Unknown                        85263
#
# [141 rows x 7 columns]

# %%
df_17 = pd.read_excel(input, header=1, sheet_name='2017')
df_17['Date Event Began'] = pd.to_datetime(df_17['Date Event Began'], errors='coerce')
df_17 = df_17.dropna(subset=['Date Event Began'])
df_17.reset_index(drop=True, inplace=True)
df_17.drop(columns=['Month', 'Time Event Began', 'Time of Restoration', 'Alert Criteria'], inplace=True)

df_17
# Out:
#     Date Event Began Date of Restoration                    Area Affected  \
# 0         2017-01-05          01/05/2017          Florida: Martin County;
# 1         2017-01-08          01/13/2017                       California
# 2         2017-01-08             Unknown                       California
# 3         2017-01-10          01/13/2017                       California
# 4         2017-01-15          01/15/2017  California: Los Angeles County;
# ..               ...                 ...                              ...
# 145       2017-12-18          12/18/2017                     Mississippi:
# 146       2017-12-19          12/19/2017         Florida: Alachua County;
# 147       2017-12-29          12/29/2017           Texas: Calhoun County;
# 148       2017-12-29             Unknown       New York: Tompkins County;
# 149       2017-12-31          01/01/2018                        Colorado:
#
#     NERC Region                 Event Type Demand Loss (MW)  \
# 0          FRCC  Suspected Physical Attack                0
# 1          WECC             Severe Weather          Unknown
# 2          WECC     Fuel Supply Deficiency                0
# 3          WECC             Severe Weather          Unknown
# 4          WECC    Transmission Disruption              176
# ..          ...                        ...              ...
# 145        SERC                  Vandalism                0
# 146        FRCC                  Vandalism                0
# 147         TRE        Suspicious Activity          Unknown
# 148        NPCC     Fuel Supply Deficiency              210
# 149        WECC                  Vandalism                0
#
#     Number of Customers Affected
# 0                              0
# 1                         106000
# 2                              0
# 3                          87000
# 4                         126000
# ..                           ...
# 145                            0
# 146                            0
# 147                      Unknown
# 148                      Unknown
# 149                            0
#
# [150 rows x 7 columns]

# %%
df_18 = pd.read_excel(input, header=1, sheet_name='2018')
df_18['Date Event Began'] = pd.to_datetime(df_18['Date Event Began'], errors='coerce')
df_18 = df_18.dropna(subset=['Date Event Began'])
df_18.reset_index(drop=True, inplace=True)
df_18.drop(columns=['Month', 'Time Event Began', 'Time of Restoration', 'Alert Criteria'], inplace=True)

df_18
# Out:
#     Date Event Began Date of Restoration  \
# 0         2018-01-01          01/02/2018
# 1         2018-01-01             Unknown
# 2         2018-01-01          01/02/2018
# 3         2018-01-02          02/12/2018
# 4         2018-01-02             Unknown
# ..               ...                 ...
# 215       2018-12-26          01/03/2019
# 216       2018-12-27          12/27/2018
# 217       2018-12-27          12/27/2018
# 218       2018-12-27          12/27/2018
# 219       2018-12-30          12/30/2018
#
#                                          Area Affected NERC Region  \
# 0                                           Tennessee:        SERC
# 1                                               Texas:         TRE
# 2                                           Tennessee:        SERC
# 3                            New York: Niagara County;        NPCC
# 4                                      South Carolina:        SERC
# ..                                                 ...         ...
# 215                           California: Kern County;        WECC
# 216                         New York: New York County;        NPCC
# 217  Maryland: Montgomery County, Prince George's C...          RF
# 218                           California: Kern County;        WECC
# 219                           Washington: King County;        WECC
#
#                     Event Type Demand Loss (MW) Number of Customers Affected
# 0               Severe Weather          Unknown                      Unknown
# 1               Severe Weather          Unknown                      Unknown
# 2            System Operations          Unknown                      Unknown
# 3       Fuel Supply Deficiency              675                      Unknown
# 4               Severe Weather                0                       717000
# ..                         ...              ...                          ...
# 215                  Vandalism                0                            0
# 216  Transmission Interruption          Unknown                      Unknown
# 217          System Operations                0                            0
# 218                  Vandalism                0                            0
# 219          System Operations                0                            0
#
# [220 rows x 7 columns]

# %%
df_19 = pd.read_excel(input, header=1, sheet_name='2019')
df_19['Date Event Began'] = pd.to_datetime(df_19['Date Event Began'], errors='coerce')
df_19 = df_19.dropna(subset=['Date Event Began'])
df_19.reset_index(drop=True, inplace=True)
df_19.drop(columns=['Month', 'Time Event Began', 'Time of Restoration', 'Alert Criteria'], inplace=True)

df_19
# Out:
#     Date Event Began Date of Restoration  \
# 0         2019-01-05          01/05/2019
# 1         2019-01-06          01/09/2019
# 2         2019-01-06          01/06/2019
# 3         2019-01-06          01/06/2019
# 4         2019-01-07          01/07/2019
# ..               ...                 ...
# 273       2019-12-18          12/18/2019
# 274       2019-12-19          12/19/2019
# 275       2019-12-24          12/24/2019
# 276       2019-12-31          12/31/2019
# 277       2019-12-31          01/01/2020
#
#                                          Area Affected NERC Region  \
# 0                                          Washington:        WECC
# 1                                          Washington:        WECC
# 2                       California: Sacramento County;        WECC
# 3    Washington: King County, Thurston County, Pier...        WECC
# 4                                            Michigan:          RF
# ..                                                 ...         ...
# 273                              Texas: Nueces County;         TRE
# 274                                          Nebraska:         MRO
# 275                                          Illinois:        SERC
# 276                                        Washington:        WECC
# 277                              Texas: Nueces County;         TRE
#
#                     Event Type Demand Loss (MW) Number of Customers Affected
# 0            System Operations                0                      Unknown
# 1               Severe Weather              230                       230000
# 2               Severe Weather              300                        90382
# 3               Severe Weather          Unknown                       230000
# 4            System Operations                0                            0
# ..                         ...              ...                          ...
# 273          System Operations                0                            0
# 274          System Operations                0                            0
# 275        Suspicious Activity                0                            0
# 276                  Vandalism                0                            0
# 277  Transmission Interruption               25                            0
#
# [278 rows x 7 columns]

# %%
df_20 = pd.read_excel(input, header=1, sheet_name='2020')
df_20['Date Event Began'] = pd.to_datetime(df_20['Date Event Began'], errors='coerce')
df_20 = df_20.dropna(subset=['Date Event Began'])
df_20.reset_index(drop=True, inplace=True)
df_20.drop(columns=['Month', 'Time Event Began', 'Time of Restoration', 'Alert Criteria'], inplace=True)

df_20
# Out:
#     Date Event Began Date of Restoration  \
# 0         2020-01-09          01/09/2020
# 1         2020-01-09          01/10/2020
# 2         2020-01-09          01/09/2020
# 3         2020-01-09          01/09/2020
# 4         2020-01-10             Unknown
# ..               ...                 ...
# 378       2020-12-24             Unknown
# 379       2020-12-25          12/25/2020
# 380       2020-12-25          12/25/2020
# 381       2020-12-25          12/25/2020
# 382       2020-12-28          12/29/2020
#
#                                          Area Affected NERC Region  \
# 0                               Arkansas: Yell County;      SPP RE
# 1                             Washington: King County;        WECC
# 2                  Minnesota: North Dakota: Wisconsin:         MRO
# 3                                            Arkansas:      SPP RE
# 4                          Tennessee: Hamilton County;        SERC
# ..                                                 ...         ...
# 378  Pennsylvania: Bucks County, Chester County, De...          RF
# 379                                        California:        WECC
# 380                                    Ohio: Kentucky:          RF
# 381  Connecticut: Maine: New Hampshire: Massachuset...        NPCC
# 382                                          Virginia:        SERC
#
#                                    Event Type Demand Loss (MW)  \
# 0    Severe Weather/Transmission Interruption                0
# 1                         Suspicious Activity                0
# 2                           System Operations                0
# 3                           System Operations          Unknown
# 4                         Suspicious Activity          Unknown
# ..                                        ...              ...
# 378  Severe Weather/Distribution Interruption          Unknown
# 379                                 Vandalism                0
# 380                       Suspicious Activity                0
# 381                            Severe Weather          Unknown
# 382                                 Vandalism                0
#
#     Number of Customers Affected
# 0                              0
# 1                              0
# 2                              0
# 3                        Unknown
# 4                        Unknown
# ..                           ...
# 378                        68114
# 379                            0
# 380                            0
# 381                        19000
# 382                            0
#
# [383 rows x 7 columns]

# %%
df_21 = pd.read_excel(input, header=1, sheet_name='2021')
df_21['Date Event Began'] = pd.to_datetime(df_21['Date Event Began'], errors='coerce')
df_21 = df_21.dropna(subset=['Date Event Began'])
df_21.reset_index(drop=True, inplace=True)
df_21.drop(columns=['Month', 'Time Event Began', 'Time of Restoration', 'Alert Criteria'], inplace=True)

df_21
# Out:
#     Date Event Began Date of Restoration  \
# 0         2021-01-01          01/01/2021
# 1         2021-01-02          01/02/2021
# 2         2021-01-04          01/04/2021
# 3         2021-01-08          01/08/2021
# 4         2021-01-10          01/13/2021
# ..               ...                 ...
# 382       2021-12-24          12/24/2021
# 383       2021-12-27          01/01/2022
# 384       2021-12-27          12/30/2021
# 385       2021-12-29          12/29/2021
# 386       2021-12-30             Unknown
#
#                                          Area Affected NERC Region  \
# 0                          California: Alameda County;        WECC
# 1                            California: Butte County;        WECC
# 2                                        Pennsylvania:          RF
# 3                            Arkansas: Prairie County;        SERC
# 4    Texas: Anderson County, Angelina County, Dalla...         TRE
# ..                                                 ...         ...
# 382                                Texas: Rusk County;         TRE
# 383                                        California:        WECC
# 384                       California: Humboldt County;        WECC
# 385                              Nevada: Clark County;        WECC
# 386             Missouri: Adair County, Putnam County;        SERC
#
#                     Event Type Demand Loss (MW) Number of Customers Affected
# 0                    Vandalism                0                            0
# 1            System Operations                8                         5803
# 2    Transmission Interruption                6                         3825
# 3                     Sabotage          Unknown                         1908
# 4               Severe Weather          Unknown                       188000
# ..                         ...              ...                          ...
# 382          System Operations          Unknown                      Unknown
# 383             Severe Weather              381                       115830
# 384          System Operations              120                        65994
# 385          System Operations                0                            0
# 386                  Vandalism                0                            0
#
# [387 rows x 7 columns]

# %%
df_22 = pd.read_excel(input, header=1, sheet_name='2022')
df_22['Date Event Began'] = pd.to_datetime(df_22['Date Event Began'], errors='coerce')
df_22 = df_22.dropna(subset=['Date Event Began'])
df_22.reset_index(drop=True, inplace=True)
df_22.drop(columns=['Month', 'Time Event Began', 'Time of Restoration', 'Alert Criteria'], inplace=True)

df_22
# Out:
#     Date Event Began Date of Restoration                     Area Affected  \
# 0         2022-01-01          01/01/2022      Washington: Thurston County;
# 1         2022-01-01          01/02/2022      Washington: Thurston County;
# 2         2022-01-01             Unknown          Georgia: Clayton County;
# 3         2022-01-01          01/01/2022  New Hampshire: Merrimack County;
# 4         2022-01-02          01/02/2022      California: Tuolumne County;
# ..               ...                 ...                               ...
# 385       2022-12-29             Unknown                             Ohio:
# 386       2022-12-30          12/30/2022           Oregon: Sherman County;
# 387       2022-12-30             Unknown     Minnesota: Washington County;
# 388       2022-12-31          01/03/2023                           Nevada:
# 389       2022-12-31          01/01/2023    California: Sacramento County;
#
#     NERC Region                 Event Type Demand Loss (MW)  \
# 0          WECC          System Operations                0
# 1          WECC          System Operations                0
# 2          SERC                  Vandalism                0
# 3          NPCC        Suspicious Activity                2
# 4          WECC             Severe Weather                3
# ..          ...                        ...              ...
# 385          RF                  Vandalism             2600
# 386        WECC  Transmission Interruption                0
# 387         MRO  Transmission Interruption          Unknown
# 388        WECC             Severe Weather          Unknown
# 389        WECC             Severe Weather          Unknown
#
#     Number of Customers Affected
# 0                              0
# 1                              0
# 2                              0
# 3                            845
# 4                           1706
# ..                           ...
# 385                      Unknown
# 386                            0
# 387                      Unknown
# 388                         3500
# 389                       161000
#
# [390 rows x 7 columns]

# %%
df_23 = pd.read_excel(input, header=1, sheet_name='2023')
df_23['Date Event Began'] = pd.to_datetime(df_23['Date Event Began'], errors='coerce')
df_23 = df_23.dropna(subset=['Date Event Began'])
df_23.reset_index(drop=True, inplace=True)
df_23.drop(columns=['Event Year', 'Event Month', 'Time Event Began', 'Time of Restoration', 'Alert Criteria'], inplace=True)

df_23
# Out:
#     Date Event Began  Date of Restoration                   Area Affected  \
# 0         2023-01-01           01/01/2023   California: Riverside County;
# 1         2023-01-01           01/01/2023  California: Sacramento County;
# 2         2023-01-01           01/01/2023         Florida: Citrus County;
# 3         2023-01-02           01/03/2023           Texas: Dallas County;
# 4         2023-01-02           01/02/2023                     New Mexico:
# ..               ...                  ...                             ...
# 162       2023-06-29              Unknown                         Indiana
# 163       2023-06-28  2023-06-28 00:00:00                         Georgia
# 164       2023-06-22  2023-06-22 00:00:00                       Louisiana
# 165       2023-06-20  2023-06-20 00:00:00                       Louisiana
# 166       2023-06-30              Unknown                     Connecticut
#
#     NERC Region                        Event Type Demand Loss (MW)  \
# 0          WECC                         Vandalism                0
# 1          WECC                 System Operations                0
# 2          SERC                         Vandalism               19
# 3           TRE                         Vandalism                0
# 4          WECC                         Vandalism              432
# ..          ...                               ...              ...
# 162          RF     - Weather or natural disaster          Unknown
# 163        SERC               - Vandalism - Theft                0
# 164        SERC  - Transmission equipment failure               17
# 165        SERC  - Transmission equipment failure                0
# 166        NPCC                         - Unknown                0
#
#     Number of Customers Affected
# 0                              0
# 1                              0
# 2                           3509
# 3                              0
# 4                              0
# ..                           ...
# 162                       140000
# 163                            0
# 164                         6242
# 165                            0
# 166                            0
#
# [167 rows x 7 columns]

# %%
df_big = pd.concat([df_02, df_03, df_04, df_05, df_06, df_07, df_08, df_09, df_10, df_11, 
                    df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19, df_20, df_21, df_22, df_23], ignore_index=True)

# df_big.to_excel('grid_outages.xlsx')
df_big.head()
# Out:
#   Date Event Began  Date of Restoration                  Area Affected  \
# 0       2002-01-30  2002-02-07 12:00:00                       Oklahoma
# 1       2002-01-29                  NaN  Metropolitan Kansas City Area
# 2       2002-01-30  2002-02-10 21:00:00                       Missouri
# 3       2002-02-27  2002-02-27 11:35:00                     California
# 4       2002-03-09  2002-03-11 12:00:00    Lower Peninsula of Michigan
#
#   NERC Region                 Event Type Demand Loss (MW)  \
# 0         SPP                  Ice Storm              500
# 1         SPP                  Ice Storm          500-600
# 2         SPP                  Ice Storm              210
# 3        WSCC  Interruption of Firm Load              300
# 4        ECAR             Severe Weather              190
#
#   Number of Customers Affected
# 0                      1881134
# 1                       270000
# 2                        95000
# 3                       255000
# 4                       190000

# %%
df_big['Date Event Began'] = pd.to_datetime(df_big['Date Event Began'], errors='coerce')

df_big['Date of Restoration'] = pd.to_datetime(df_big['Date of Restoration'], errors='coerce')
# df_big = df_big.dropna(subset=['Date of Restoration'])
df_big.head()
# Out:
#   Date Event Began Date of Restoration                  Area Affected  \
# 0       2002-01-30 2002-02-07 12:00:00                       Oklahoma
# 1       2002-01-29                 NaT  Metropolitan Kansas City Area
# 2       2002-01-30 2002-02-10 21:00:00                       Missouri
# 3       2002-02-27 2002-02-27 11:35:00                     California
# 4       2002-03-09 2002-03-11 12:00:00    Lower Peninsula of Michigan
#
#   NERC Region                 Event Type Demand Loss (MW)  \
# 0         SPP                  Ice Storm              500
# 1         SPP                  Ice Storm          500-600
# 2         SPP                  Ice Storm              210
# 3        WSCC  Interruption of Firm Load              300
# 4        ECAR             Severe Weather              190
#
#   Number of Customers Affected
# 0                      1881134
# 1                       270000
# 2                        95000
# 3                       255000
# 4                       190000

# %%
df_big.dtypes
# Out:
# Date Event Began                datetime64[ns]
# Date of Restoration             datetime64[ns]
# Area Affected                           object
# NERC Region                             object
# Event Type                              object
# Demand Loss (MW)                        object
# Number of Customers Affected            object
# dtype: object

# %%
df_big.reset_index(drop=True, inplace=True)

# # df_big.head(10)
# df_big.dtypes

# %%
import us

states = [state.name for state in us.states.STATES_AND_TERRITORIES]
abbreviations = [state.abbr for state in us.states.STATES_AND_TERRITORIES]
all_states = states + abbreviations

# %%
def extract_state_names(text, all_states):
    for state in all_states:
        if state in text:
            return state

# %%
df_big['State Names'] = df_big['Area Affected'].apply(lambda x: extract_state_names(x, all_states))

# %%
df_big.to_excel('grid_outages0.xlsx')

df_big.head()
# Out:
#   Date Event Began Date of Restoration                  Area Affected  \
# 0       2002-01-30 2002-02-07 12:00:00                       Oklahoma
# 1       2002-01-29                 NaT  Metropolitan Kansas City Area
# 2       2002-01-30 2002-02-10 21:00:00                       Missouri
# 3       2002-02-27 2002-02-27 11:35:00                     California
# 4       2002-03-09 2002-03-11 12:00:00    Lower Peninsula of Michigan
#
#   NERC Region                 Event Type Demand Loss (MW)  \
# 0         SPP                  Ice Storm              500
# 1         SPP                  Ice Storm          500-600
# 2         SPP                  Ice Storm              210
# 3        WSCC  Interruption of Firm Load              300
# 4        ECAR             Severe Weather              190
#
#   Number of Customers Affected State Names
# 0                      1881134    Oklahoma
# 1                       270000      Kansas
# 2                        95000    Missouri
# 3                       255000  California
# 4                       190000    Michigan

# %%
df_states = pd.read_excel('grid_outages0.xlsx')
df_states.head()
# Out:
#    Unnamed: 0 Date Event Began Date of Restoration  \
# 0           0       2002-01-30 2002-02-07 12:00:00
# 1           1       2002-01-29                 NaT
# 2           2       2002-01-30 2002-02-10 21:00:00
# 3           3       2002-02-27 2002-02-27 11:35:00
# 4           4       2002-03-09 2002-03-11 12:00:00
#
#                    Area Affected NERC Region                 Event Type  \
# 0                       Oklahoma         SPP                  Ice Storm
# 1  Metropolitan Kansas City Area         SPP                  Ice Storm
# 2                       Missouri         SPP                  Ice Storm
# 3                     California        WSCC  Interruption of Firm Load
# 4    Lower Peninsula of Michigan        ECAR             Severe Weather
#
#   Demand Loss (MW) Number of Customers Affected State Names
# 0              500                      1881134    Oklahoma
# 1          500-600                       270000      Kansas
# 2              210                        95000    Missouri
# 3              300                       255000  California
# 4              190                       190000    Michigan

# %%
state_abbreviations = {state.abbr: state.name for state in us.states.STATES}

# %%
def convert_abbreviations_to_full_names(state):
    if state in state_abbreviations:
        return state_abbreviations[state]
    else:
        return state

# %%
df_states['State Names'] = df_states['State Names'].apply(convert_abbreviations_to_full_names)

# %%
df_states.head()
# Out:
#    Unnamed: 0 Date Event Began Date of Restoration  \
# 0           0       2002-01-30 2002-02-07 12:00:00
# 1           1       2002-01-29                 NaT
# 2           2       2002-01-30 2002-02-10 21:00:00
# 3           3       2002-02-27 2002-02-27 11:35:00
# 4           4       2002-03-09 2002-03-11 12:00:00
#
#                    Area Affected NERC Region                 Event Type  \
# 0                       Oklahoma         SPP                  Ice Storm
# 1  Metropolitan Kansas City Area         SPP                  Ice Storm
# 2                       Missouri         SPP                  Ice Storm
# 3                     California        WSCC  Interruption of Firm Load
# 4    Lower Peninsula of Michigan        ECAR             Severe Weather
#
#   Demand Loss (MW) Number of Customers Affected State Names
# 0              500                      1881134    Oklahoma
# 1          500-600                       270000      Kansas
# 2              210                        95000    Missouri
# 3              300                       255000  California
# 4              190                       190000    Michigan

# %%
df_states.drop(['Area Affected'], axis=1, inplace=True)
df_states.head()
# Out:
#    Unnamed: 0 Date Event Began Date of Restoration NERC Region  \
# 0           0       2002-01-30 2002-02-07 12:00:00         SPP
# 1           1       2002-01-29                 NaT         SPP
# 2           2       2002-01-30 2002-02-10 21:00:00         SPP
# 3           3       2002-02-27 2002-02-27 11:35:00        WSCC
# 4           4       2002-03-09 2002-03-11 12:00:00        ECAR
#
#                   Event Type Demand Loss (MW) Number of Customers Affected  \
# 0                  Ice Storm              500                      1881134
# 1                  Ice Storm          500-600                       270000
# 2                  Ice Storm              210                        95000
# 3  Interruption of Firm Load              300                       255000
# 4             Severe Weather              190                       190000
#
#   State Names
# 0    Oklahoma
# 1      Kansas
# 2    Missouri
# 3  California
# 4    Michigan

# %%
# df_states.to_excel('grid_data_clean0.xlsx')

# %%
consolidated_data = df_states['Event Type'].value_counts()
consolidated_data.head(40)
# Out:
# Severe Weather                                878
# Vandalism                                     511
# System Operations                             410
# Suspicious Activity                           193
# Transmission Interruption                     177
# Severe Weather - Thunderstorms                 97
# Suspected Physical Attack                      87
# Severe Thunderstorms                           70
# Fuel Supply Deficiency                         59
# Winter Storm                                   51
# Severe Weather/Transmission Interruption       48
# Actual Physical Attack                         45
# Ice Storm                                      42
# Physical Attack - Vandalism                    40
# Sabotage                                       35
# High Winds                                     33
# Physical Attack                                30
# Thunderstorms                                  30
# Electrical System Separation (Islanding)       30
# Public Appeal to Reduce Electricity Usage      27
# Physical Attack; Vandalism                     24
# Actual Physical Attack/Vandalism               24
# Cyber Event                                    23
# Severe Storm                                   22
# Made Public Appeals                            22
# Severe Weather - Hurricane Sandy               21
# Suspected Physical Attack - Vandalism          16
# Generation Inadequacy                          15
# Weather                                        14
# Wind Storm                                     14
# Severe Storms                                  13
# Severe Weather - Winter Storm                  13
# Suspected Cyber Attack                         13
# Voltage Reduction                              13
# Electrical System Separation                   12
# Severe Thunderstorm                            12
# Public Appeal due to Severe Weather - Cold     12
# Load Shedding                                  11
# Fuel Supply Emergency - Coal                   11
# Severe Weather - Winter                        11
# Name: Event Type, dtype: int64

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Storm', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Weather', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Major Storm', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather - Snow/Ice', 'Winter Storm')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Ice Storm', 'Winter Storm')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather - Ice/Snow', 'Winter Storm')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather - Winter Storm', 'Winter Storm')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather - Thunderstorms', 'Thunderstorms')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Physical Attack - Vandalism', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Suspected Physical Attack', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Actual Physical Attack', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Thunderstorms', 'Thunderstorms')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Thunderstorm', 'Thunderstorms')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Actual Physical Attack/Vandalism', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Physical Attack/Vandalism', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Physcial Attack; Vandalism', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Sabotage', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Suspected Physical Attack - Vandalism', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Physical Attack; Vandalism', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather/Distribution Interruption', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather/Transmission Interruption', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('High Winds', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Wind Storm', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather - Wind', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('High Winds and Rain', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather/Transmisison Interruption', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather/Transmisison Interruption', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('- Weather or natural disaster', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Storm', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Storms', 'Severe Weather')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Strong Thunderstorms', 'Thunderstorms')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Suspected Cyber Attack', 'Cyber Event')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Severe Weather - Winter', 'Winter Storm')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Ice/Snow Storm', 'Winter Storm')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Islanding', 'Electrical System Separation (Islanding)')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Electrical System Separation', 'Electrical System Separation (Islanding)')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Voltage Reduction due to Severe Weather - Cold', 'Voltage Reduction')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Voltage Reduction/Load Shed', 'Voltage Reduction')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Load Shedding', 'Voltage Reduction')

# %%
df_states['Event Type'] = df_states['Event Type'].replace('Vandalism', 'Physical Attack')

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Hurricane.*', 'Natural Disaster', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Earthquake.*', 'Natural Disaster', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Winter.*', 'Winter Storm', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Ice.*', 'Winter Storm', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Snow.*', 'Winter Storm', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Vandalism.*', 'Physical Attack', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Physical.*', 'Physical Attack', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Generation.*', 'Voltage Reduction', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Load.*', 'Voltage Reduction', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Severe.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Storm.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Storms.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Thunderstorm.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Winds.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Wind.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Islanding.*', 'Electrical System Separation (Islanding)', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Suspicious.*', 'Suspicious Activity', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Cyber.*', 'Cyber Event', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Fuel.*', 'Fuel Supply Deficiency', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Voltage.*', 'Voltage Reduction', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Failure.*', 'Equipment Failure', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Malfunction.*', 'Equipment Failure', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Interruption.*', 'Transmission Interruption', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Public.*', 'Public Appeals', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Weather.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Tornado.*', 'Natural Disaster', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Attack.*', 'Physical Attack', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*attack.*', 'Physical Attack', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Lightning.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Vandalsim.*', 'Physical Attack', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Sabotage.*', 'Physical Attack', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Tripped.*', 'Unit Tripped', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Fire.*', 'Fire', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Equipment.*', 'Equipment Failure', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*equipment.*', 'Equipment Failure', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Fault.*', 'Equipment Failure', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Transmission.*', 'Transmission Interruption', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Flood.*', 'Natural Disaster', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Fire.*', 'Natural Disaster', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Heat.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Deficiency.*', 'Fuel Supply Deficiency', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Unit.*', 'Unit Tripped', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Unknown.*', 'Other', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Electric.*', 'Electrical System Separation (Islanding)', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Highwinds.*', 'Severe Weather', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*reductions.*', 'Voltage Reduction', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Resources.*', 'Fuel Supply Deficiency', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Wildfire.*', 'Natural Disaster', regex=True)

# %%
df_states['Event Type'] = df_states['Event Type'].str.replace(r'.*Tropical.*', 'Natural Disaster', regex=True)

# %%
counts = df_states['Event Type'].value_counts()
mask = df_states['Event Type'].isin(counts[counts == 1].index)
df_states.loc[mask, 'Event Type'] = 'Other'

# %%
df_states['Event Type'].value_counts()
# Out:
# Severe Weather                              1590
# Physical Attack                              874
# System Operations                            410
# Transmission Interruption                    207
# Suspicious Activity                          199
# Voltage Reduction                            167
# Natural Disaster                             123
# Fuel Supply Deficiency                       103
# Public Appeals                                82
# Electrical System Separation (Islanding)      61
# Equipment Failure                             45
# Cyber Event                                   41
# Other                                         27
# Unit Tripped                                  20
# Name: Event Type, dtype: int64

# %%
df_states.dtypes
# df_states.head(30)
# Out:
# Unnamed: 0                               int64
# Date Event Began                datetime64[ns]
# Date of Restoration             datetime64[ns]
# NERC Region                             object
# Event Type                              object
# Demand Loss (MW)                        object
# Number of Customers Affected            object
# State Names                             object
# dtype: object

# %%
df_states.drop(columns='Unnamed: 0', inplace=True)
df_states.dtypes
# Out:
# Date Event Began                datetime64[ns]
# Date of Restoration             datetime64[ns]
# NERC Region                             object
# Event Type                              object
# Demand Loss (MW)                        object
# Number of Customers Affected            object
# State Names                             object
# dtype: object

# %%
df_states['Number of Customers Affected'].value_counts()
# Out:
# 0          911
# Unknown    497
# 0          315
# -           27
# UNK         26
#           ...
# 53064        1
# 931000       1
# 181700       1
# 14500        1
# 6242         1
# Name: Number of Customers Affected, Length: 1370, dtype: int64

# %%
print(df_states['Number of Customers Affected'].isna())

df_states['Number of Customers Affected'].replace(["UNK", "-"], "Unknown", inplace=True)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3944    False
# 3945    False
# 3946    False
# 3947    False
# 3948    False
# Name: Number of Customers Affected, Length: 3949, dtype: bool

# %%
df_states['Number of Customers Affected'].value_counts()
# Out:
# 0          911
# Unknown    550
# 0          315
# 50000       25
# 1           17
#           ...
# 931000       1
# 181700       1
# 14500        1
# 71500        1
# 6242         1
# Name: Number of Customers Affected, Length: 1368, dtype: int64

# %%
df_states.to_excel('grid_cleaned_1.xlsx')
